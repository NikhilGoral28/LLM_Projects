# %%
from secret_key import second_key

print(second_key)
# Out:
# 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

# %%
from secret_key import second_key
import os
os.environ['OPENAI_API_KEY'] = second_key

# %%
print(os.environ['OPENAI_API_KEY'])
# Out:
# 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

# %%
from langchain.llms import OpenAI

llm = OpenAI(temperature=0.6)
name = llm("I want to open a restaurant. Give me a unique name for it.")
print(name)
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_21676\2030794400.py:3: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm = OpenAI(temperature=0.6)
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_21676\2030794400.py:4: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   name = llm("I want to open a restaurant. Give me a unique name for it.")
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 from langchain.llms import OpenAI
# ...

# %%
from langchain.prompts import PromptTemplate

prompt_template_name  = PromptTemplate(
    input_variables=["cuisine_type"],
    template="I want to open a restaurant that serves {cuisine_type}. Give me a unique name for it."
)
prompt_template_name.format(cuisine_type="Mexican food")
# Out:
# 'I want to open a restaurant that serves Mexican food. Give me a unique name for it.'

# %%
from langchain.chains import LLMChain

chain = LLMChain(llm=llm, prompt=prompt_template_name)
chain.run("Italian food")
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_22404\337462451.py:3: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=llm, prompt=prompt_template_name)
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_22404\337462451.py:4: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chain.run("Italian food")
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 from langchain.chains import LLMChain
#       3 chain = LLMChain(llm=llm, prompt=prompt_template_name)
# ----> 4 chain.run("Italian food")
#
# ...

# %%
llm = OpenAI(temperature=0.6)

prompt_template_name = PromptTemplate(
    input_variables=['cuisine']
    template = " I want to open a restaurant for {cuisine} food. Suggest a fency name food items"

)

name_chain  = LLMChain(llm=llm, prompt=prompt_template_name)

prompt_template_items = PromptTemplate(
    input_variables= ['restaurant_name']
    template= """ Suggest some menu items for {restaurant_name}. Return it as a comma seperated list """

)

food_items_chain = LLMChain(llm=llm, prompt = prompt_template_items)

# %%
from langchain.chains import SimpleSequentialChain

chain = SimpleSequentialChain(chains = [name_chain, food_items_chain])
response = chain.run("Indian")

print(response)

# %%
llm = OpenAI(temperature=0.6)

prompt_template_name = PromptTemplate(
    input_variables=['cuisine']
    template = " I want to open a restaurant for {cuisine} food. Suggest a fency name food items"

)

name_chain  = LLMChain(llm=llm, prompt=prompt_template_name, output_key = 'restaurant_name')

prompt_template_items = PromptTemplate(
    input_variables= ['restaurant_name']
    template= """ Suggest some menu items for {restaurant_name}."""

)

food_items_chain = LLMChain(llm=llm, prompt = prompt_template_items, output_key = 'menu_items')

# %%
from langchain.chains import SequentialChain


Chain = SequentialChain(
    chains = [name_chain, food_items_chain], 
    input_variables = ['cuisine'],
    output_variables = ['restaurant_name', 'menu_items']
)
Chain({'cuisine': 'Thai'})

# %%
#agent

from langchain.agents import load_tools, AgentType
from langchain.agents import initialize_agent

from langchain.llms import OpenAI

tools = load_tools(["wikipedia", "llm-math"], llm=llm)

agent=initialize_agent(
    tools, llm, agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose=True
)

agent.run("What is the capital of France? Also what is 15 raised to the power of 2?")

# %%
#using serpapi key
from secret_key import serpapi_key
import os
os.environ['SERPAPI_API_KEY'] = serpapi_key

# %%
llm = OpenAI(Temperature=0)

#the tools we'll give the agent acess to. Note that 'LLm-math' tool uses an LLM

tools = load_tools(["serpapi",'llm-math'], llm=llm)

#finally lets initialize an agent with the tools, the language model and the type of 

agent = initialize_agent(tools, llm, agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose = True)

agent.run("What is the GDP of US in 2025 ?")

# %% [markdown]
# memory

# %%
#memory
chain = LLMChain(llm=llm, prompt=prompt_template_name)
name  = chain.run("Japanese food")

print(name)

# %%
name = chain.run("Indian")

# %%
type(chain.memory)

# %%
from langchain.memory import ConversationBufferMemory

memory = ConversationBufferMemory()
chain = LLMChain(llm=llm, prompt=prompt_template_name, memory=memory)
name = chain.run("indian")
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_17212\701500315.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from langchain.memory import ConversationBufferMemory
#       3 memory = ConversationBufferMemory()
# ----> 4 chain = LLMChain(llm=llm, prompt=prompt_template_name, memory=memory)
#
# NameError: name 'LLMChain' is not defined

# %%
name = chain.run("Japanese")
print(name)

# %%
print(chain.memory.buffer)

# %%
from langchain.chains import ConversationChain

convo = ConversationChain(llm=llm, memory=memory)

print(convo.prompt.template)

# %%
convo.run("who won first first cricket world cup ?")

# %%
convo.run("What is 5+5?")

# %%
convo.run("Who was the captain of that team ?")

# %%
print(convo.memory.buffer)
